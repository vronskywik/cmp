# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
days = np.arange(1, 11)
prices = np.array([100, 110, 105, 115, 120, 118, 122, 125, 130, 128])
volume = np.array([200, 250, 220, 270, 300, 280, 320, 350, 380, 360])

# Create figure and primary axis for price line graph
fig, ax1 = plt.subplots()

# Plot price line graph
ax1.plot(days, prices, color='blue', label='Price')
ax1.set_xlabel('Days')
ax1.set_ylabel('Price', color='blue')
ax1.tick_params('y', colors='blue')

1

# Plot volume histogram
ax2.bar(days, volume, color='green', alpha=0.5, label='Volume')
ax2.set_ylabel('Volume', color='green')
ax2.tick_params('y', colors='green')

# Add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

# Add title
plt.title('Price Line Graph with Volume Histogram')

# Show plot
plt.grid(True)
plt.show()
